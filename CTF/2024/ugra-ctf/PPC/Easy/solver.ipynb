# %%
# !pip install sympy latex2sympy2 "pix2tex[gui]"
# Out:
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (1.12)
# Collecting latex2sympy2
#   Downloading latex2sympy2-1.9.1-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.8/89.8 kB 1.2 MB/s eta 0:00:00
# Collecting pix2tex[gui]
#   Downloading pix2tex-0.1.2-py3-none-any.whl (422 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.9/422.9 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy) (1.3.0)
# Collecting antlr4-python3-runtime==4.7.2 (from latex2sympy2)
#   Downloading antlr4-python3-runtime-4.7.2.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.10/dist-packages (from pix2tex[gui]) (4.66.1)
# Collecting munch>=2.5.0 (from pix2tex[gui])
#   Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from pix2tex[gui]) (2.1.0+cu121)
# Requirement already satisfied: opencv-python-headless>=4.1.1.26 in /usr/local/lib/python3.10/dist-packages (from pix2tex[gui]) (4.9.0.80)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from pix2tex[gui]) (2.31.0)
# Collecting einops>=0.3.0 (from pix2tex[gui])
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.7 MB/s eta 0:00:00
# Collecting x-transformers==0.15.0 (from pix2tex[gui])
#   Downloading x_transformers-0.15.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: transformers>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pix2tex[gui]) (4.35.2)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from pix2tex[gui]) (0.15.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from pix2tex[gui]) (1.23.5)
# Requirement already satisfied: Pillow>=9.1.0 in /usr/local/lib/python3.10/dist-packages (from pix2tex[gui]) (9.4.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from pix2tex[gui]) (6.0.1)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pix2tex[gui]) (1.5.3)
# Collecting timm==0.5.4 (from pix2tex[gui])
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: albumentations>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from pix2tex[gui]) (1.3.1)
# Collecting PyQt6 (from pix2tex[gui])
#   Downloading PyQt6-6.6.1-cp38-abi3-manylinux_2_28_x86_64.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 38.0 MB/s eta 0:00:00
# Collecting PyQt6-WebEngine (from pix2tex[gui])
#   Downloading PyQt6_WebEngine-6.6.0-cp37-abi3-manylinux_2_28_x86_64.whl (257 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.6/257.6 kB 17.5 MB/s eta 0:00:00
# Collecting pyside6 (from pix2tex[gui])
#   Downloading PySide6-6.6.1-cp38-abi3-manylinux_2_28_x86_64.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.8 MB/s eta 0:00:00
# Collecting pynput (from pix2tex[gui])
#   Downloading pynput-1.7.6-py2.py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 6.0 MB/s eta 0:00:00
# Collecting screeninfo (from pix2tex[gui])
#   Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.5.4->pix2tex[gui]) (0.16.0+cu121)
# Collecting entmax (from x-transformers==0.15.0->pix2tex[gui])
#   Downloading entmax-1.3-py3-none-any.whl (13 kB)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from albumentations>=0.5.2->pix2tex[gui]) (1.11.4)
# Requirement already satisfied: scikit-image>=0.16.1 in /usr/local/lib/python3.10/dist-packages (from albumentations>=0.5.2->pix2tex[gui]) (0.19.3)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from albumentations>=0.5.2->pix2tex[gui]) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pix2tex[gui]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->pix2tex[gui]) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->pix2tex[gui]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->pix2tex[gui]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->pix2tex[gui]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->pix2tex[gui]) (2024.2.2)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.0->pix2tex[gui]) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->pix2tex[gui]) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->pix2tex[gui]) (4.9.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->pix2tex[gui]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->pix2tex[gui]) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->pix2tex[gui]) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->pix2tex[gui]) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.18.0->pix2tex[gui]) (23.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.18.0->pix2tex[gui]) (2023.12.25)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.18.0->pix2tex[gui]) (0.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pynput->pix2tex[gui]) (1.16.0)
# Collecting evdev>=1.3 (from pynput->pix2tex[gui])
#   Downloading evdev-1.6.1.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-xlib>=0.17 (from pynput->pix2tex[gui])
#   Downloading python_xlib-0.33-py2.py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.2/182.2 kB 18.9 MB/s eta 0:00:00
# Collecting PyQt6-sip<14,>=13.6 (from PyQt6->pix2tex[gui])
#   Downloading PyQt6_sip-13.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.3/299.3 kB 22.0 MB/s eta 0:00:00
# Collecting PyQt6-Qt6>=6.6.0 (from PyQt6->pix2tex[gui])
#   Downloading PyQt6_Qt6-6.6.1-py3-none-manylinux_2_28_x86_64.whl (67.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 MB 4.8 MB/s eta 0:00:00
# Collecting PyQt6-WebEngine-Qt6>=6.6.0 (from PyQt6-WebEngine->pix2tex[gui])
#   Downloading PyQt6_WebEngine_Qt6-6.6.1-py3-none-manylinux_2_28_x86_64.whl (91.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.5/91.5 MB 6.5 MB/s eta 0:00:00
# Collecting shiboken6==6.6.1 (from pyside6->pix2tex[gui])
#   Downloading shiboken6-6.6.1-cp38-abi3-manylinux_2_28_x86_64.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.2/245.2 kB 17.9 MB/s eta 0:00:00
# Collecting PySide6-Essentials==6.6.1 (from pyside6->pix2tex[gui])
#   Downloading PySide6_Essentials-6.6.1-cp38-abi3-manylinux_2_28_x86_64.whl (82.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.3/82.3 MB 6.9 MB/s eta 0:00:00
# Collecting PySide6-Addons==6.6.1 (from pyside6->pix2tex[gui])
#   Downloading PySide6_Addons-6.6.1-cp38-abi3-manylinux_2_28_x86_64.whl (125.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 MB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from qudida>=0.0.4->albumentations>=0.5.2->pix2tex[gui]) (1.2.2)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations>=0.5.2->pix2tex[gui]) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations>=0.5.2->pix2tex[gui]) (2024.1.30)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.16.1->albumentations>=0.5.2->pix2tex[gui]) (1.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7.1->pix2tex[gui]) (2.1.5)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations>=0.5.2->pix2tex[gui]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations>=0.5.2->pix2tex[gui]) (3.2.0)
# Building wheels for collected packages: antlr4-python3-runtime, evdev
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.7.2-py3-none-any.whl size=140930 sha256=edb3622e4168de3e229cbccbcbcfb92695b0d446ab08081c47fb1a86bbf98f49
#   Stored in directory: /root/.cache/pip/wheels/79/20/ec/30bf7dabc29319ccc0d0c96f910a640513a3c81faa960fed43
#   Building wheel for evdev (setup.py) ... done
#   Created wheel for evdev: filename=evdev-1.6.1-cp310-cp310-linux_x86_64.whl size=83725 sha256=a1e71d5723e6c7331f48fb37db7bb3bea234f46b6f328411546d3c4c8b0c7b87
#   Stored in directory: /root/.cache/pip/wheels/bb/6e/51/0c0f5677bd58c532c42e13e7d93803fbf8d5d3bf5bfc5b0220
# Successfully built antlr4-python3-runtime evdev
# Installing collected packages: PyQt6-WebEngine-Qt6, PyQt6-Qt6, evdev, antlr4-python3-runtime, shiboken6, screeninfo, python-xlib, PyQt6-sip, munch, einops, PySide6-Essentials, PyQt6, pynput, latex2sympy2, PySide6-Addons, PyQt6-WebEngine, entmax, x-transformers, timm, pyside6, pix2tex
# Successfully installed PyQt6-6.6.1 PyQt6-Qt6-6.6.1 PyQt6-WebEngine-6.6.0 PyQt6-WebEngine-Qt6-6.6.1 PyQt6-sip-13.6.0 PySide6-Addons-6.6.1 PySide6-Essentials-6.6.1 antlr4-python3-runtime-4.7.2 einops-0.7.0 entmax-1.3 evdev-1.6.1 latex2sympy2-1.9.1 munch-4.0.0 pix2tex-0.1.2 pynput-1.7.6 pyside6-6.6.1 python-xlib-0.33 screeninfo-0.8.1 shiboken6-6.6.1 timm-0.5.4 x-transformers-0.15.0

# %%
from base64 import b64decode
from io import BytesIO

import requests
from latex2sympy2 import latex2sympy
from PIL import Image
from pix2tex.cli import LatexOCR

model_latexOCR = LatexOCR()

url = "https://peterparker.q.2024.ugractf.ru/uxnor4rbzpscdc2z/"


def base64_to_img(buff: str):
    return Image.open(BytesIO(b64decode(buff.split("data:image/png;base64,")[1])))


def img_to_latex(img: Image):
    return model_latexOCR(img)


def get_state():
    response = requests.get(url + "state")
    return response.json()


def click(data: dict = {}):
    response = requests.post(url + "click", json=data)
    return response.json()


data = get_state()
counter = data["counter"]
print(data)
while counter > 0:
    data = click()
    counter = data["counter"]
    if not data["need_captcha"]:
        continue
    print(f"Trying to solve captcha {counter} left")
    image = base64_to_img(data["picture"])
    latex = img_to_latex(image)
    try:
        sympy_expr = latex2sympy(latex.replace("\ ", "").replace(" ", ""))
    except Exception as e:
        print(f"Error: {e}")
        continue
    try:
        result = round(sympy_expr.evalf(), 3)
        data = click({"captcha_response": float(result)})
    except Exception as e:
        print(f"Error: {e} ~ {result}")
        continue
    if data.get("retry_captcha", False):
        print(f"Result: {result} is incorrect")
    else:
        print(f"Result: {result} is correct")


print(data["flag"])
# Out:
# {'counter': 1540, 'flag': None}
# Trying to solve captcha 1540 left
# Result: -0.041 is correct
# Trying to solve captcha 1530 left
# Result: -37.089 is incorrect
# Trying to solve captcha 1530 left
# Result: -15638.226 is incorrect
# Trying to solve captcha 1530 left
# Result: 9.143 is correct
# Trying to solve captcha 1520 left
# Error: Cannot round symbolic expression ~ 9.143
# Trying to solve captcha 1520 left
# Result: 103.385 is correct
# Trying to solve captcha 1510 left
# Result: -690.857 is correct
# Trying to solve captcha 1500 left
# Error: Cannot round symbolic expression ~ -690.857
# Trying to solve captcha 1500 left
# Result: 379.750 is correct
# Trying to solve captcha 1490 left
# Result: 101564.550 is correct
# Trying to solve captcha 1480 left
# Result: -10.727 is incorrect
# Trying to solve captcha 1480 left
# Result: -0.050 is correct
# Trying to solve captcha 1470 left
# Error: I expected something else here
# {\frac{1}{2\cdot2-((7-0)\cdot2\cdot8\cdot2\cdot(7-(1\cdot8-(7-(5+4)))\cdot(1-5)-2)-(3+3)\cdot(1+3-4)}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
# Trying to solve captcha 1470 left
# Error: Cannot round symbolic expression ~ -0.050
# Trying to solve captcha 1470 left
# Result: -1176.250 is correct
# Trying to solve captcha 1460 left
# Result: -11.598 is correct
# Trying to solve captcha 1450 left
# Error: I don't understand this
# \vartheta+7+\frac{(2\cdot{\bf\Xi}(8-0)+4)\cdot\vartheta}{7\cdot{\bf\Xi}(6+4+2)\cdot2\cdot\vartheta\cdot2\cdot5-8}-\left(\frac{2}{3}+7+2-3\right)
# ~~~~~~~~~~~~~~~~~~~~~~~~~~^
# Trying to solve captcha 1450 left
# Result: -0.667 is incorrect
# Trying to solve captcha 1450 left
